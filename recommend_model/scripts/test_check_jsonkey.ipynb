# %%
import chromadb

client = chromadb.HttpClient(host="localhost", port=8000)

col = client.get_collection("fashion_items_pants")
res = col.get(
    ids=["01_sou_001111_005555_wear_04bottom_01pants_woman"],
    include=["metadatas"]
)
print(res)
# Out:
# {'ids': ['01_sou_001111_005555_wear_04bottom_01pants_woman'], 'embeddings': None, 'metadatas': [{'category': 'PANTS', 'label_json_key': 'label_data/PANTS/VL_PANTS_bottom/01_sou_001111_005555_wear_04bottom_01pants_woman.json', 'label_name': 'pants', 'local_image_path': 'C:\\Users\\ehjun\\Documents\\데브코스데이터\\temp\\008.의류_통합_데이터(착용_이미지,_치수_및_원단_정보)\\01-1.정식개방데이터\\Validation\\01.원천데이터\\이미지데이터\\하의\\VS_하의_bottom\\01_sou_001111_005555_wear_04bottom_01pants_woman.jpg', 'is_onepiece': False, 'image_id': '01_sou_001111_005555_wear_04bottom_01pants_woman', 'used_part_fallback': False}], 'documents': None, 'data': None, 'uris': None, 'included': ['metadatas']}

# %%
metadatas[0]
